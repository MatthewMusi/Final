# %%
import pandas as pd
import numpy as np 
import mean

pb_parks = pd.read_csv("ParkEquip.csv")

i = 0

equip_count = pb_parks["equipment_type"].value_counts()

equip_variety = []
equip_amount = []

pb_parks.groupby(["equipment_type", "ward"])
## Parks will be grouped by their ward/location and
## by what equipment_types they have.

## The count in equip_count will be used with the groupby
## to rank the neighborhoods based on the park appliances 
## that they have.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-a68951097ec3> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import mean
#       4
#       5 pb_parks = pd.read_csv("ParkEquip.csv")
#
# ModuleNotFoundError: No module named 'pandas'
